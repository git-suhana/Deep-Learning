# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
import numpy as np

# %%
image= cv2.imread('waterfall.jpg')

# %%
image.shape
# Out:
# (251, 201, 3)

# %%
image
# Out:
# array([[[ 57,  41,  25],
#         [ 28,  18,   1],
#         [ 21,  19,   1],
#         ...,
#         [130, 129, 108],
#         [ 29,  28,   7],
#         [ 36,  35,  14]],
#
#        [[ 52,  39,  23],
#         [ 36,  28,  11],
#         [ 28,  30,  11],
#         ...,
#         [ 48,  47,  26],
#         [ 91,  90,  69],
#         [ 40,  39,  18]],
#
#        [[ 62,  55,  38],
#         [ 14,  12,   0],
#         [  8,  17,   0],
#         ...,
#         [ 62,  61,  40],
#         [ 48,  47,  26],
#         [ 29,  28,   7]],
#
#        ...,
#
#        [[ 32,  26,   7],
#         [ 32,  26,   7],
#         [ 33,  27,   8],
#         ...,
#         [ 33,  27,   8],
#         [ 33,  27,   8],
#         [ 33,  27,   8]],
#
#        [[ 32,  26,   7],
#         [ 32,  26,   7],
#         [ 33,  27,   8],
#         ...,
#         [ 33,  27,   8],
#         [ 33,  27,   8],
#         [ 33,  27,   8]],
#
#        [[ 32,  26,   7],
#         [ 32,  26,   7],
#         [ 33,  27,   8],
# ...

# %%
h,w= image.shape[:2]

# %%
h
# Out:
# 251

# %%
w
# Out:
# 201

# %%
image= cv2.imread('waterfall.jpg')
import matplotlib.pyplot as plt
plt.imshow(image)

# %%
image= cv2.imread('waterfall.jpg')
cv2.imshow('waterfalls',image)
cv2.waitKey(0)             #is used to display an image in a window for a specified amount of time.
cv2.destroyAllWindows()

# %%
x= cv2.imread('nature.jpg')

# %%
h,w= x.shape[:2]

# %%
h
# Out:
# 2948

# %%
w
# Out:
# 4390

# %%
x=cv2.imread('nature.jpg')
cv2.imshow('nature',x)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(x)

# %%
import matplotlib.pyplot as plt
plt.imshow(image)

# %%
image.shape
# Out:
# (251, 201, 3)

# %%
#resize the picture 'image'
image= cv2.imread('waterfall.jpg')
img= cv2.resize(image,(200,100))

# %%
cv2.imshow('waterfalls',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
#resize the picture 'x'
x= cv2.imread('nature.jpg')
x1= cv2.resize(x,(1048,2050))

# %%
cv2.imshow('nature',x1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
x= cv2.imread('nature.jpg')
x2= cv2.resize(x,(750,500))

# %%
import matplotlib.pyplot as plt
plt.imshow(x1)

# %%
cv2.imshow('nature',x2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt
plt.imshow(x2)

# %%
#greyscale conversion

img1= cv2.imread('waterfall.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img1)

# %%
x3= cv2.imread('nature.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(x3)

# %%
cv2.imwrite('nature.jpg',x3)
# Out:
# True
